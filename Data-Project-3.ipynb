# %%
import requests
import json
import pandas as pd
import datetime
import matplotlib.pyplot as plt

# %%
apikey = "EV1DTA3FP15KJHP6"
stocks = ['GOOGL', 'AMZN', 'AAPL', 'META', 'MSFT', 'SNAP']
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&interval=5min&apikey=' + 'apikey' + '&symbol='
data = []

for stock in stocks:
    r = requests.get(url + stock).json()
    data.append(r)

print(data)
# Out:
# [{'Meta Data': {'1. Information': 'Monthly Prices (open, high, low, close) and Volumes', '2. Symbol': 'GOOGL', '3. Last Refreshed': '2024-01-02', '4. Time Zone': 'US/Eastern'}, 'Monthly Time Series': {'2024-01-02': {'1. open': '138.5500', '2. high': '139.4500', '3. low': '136.4800', '4. close': '138.1700', '5. volume': '23599843'}, '2023-12-29': {'1. open': '131.8600', '2. high': '142.6800', '3. low': '127.9000', '4. close': '139.6900', '5. volume': '619214883'}, '2023-11-30': {'1. open': '124.0700', '2. high': '139.4200', '3. low': '123.7150', '4. close': '132.5300', '5. volume': '535336827'}, '2023-10-31': {'1. open': '131.2100', '2. high': '141.2200', '3. low': '120.2057', '4. close': '124.0800', '5. volume': '680762930'}, '2023-09-29': {'1. open': '137.4550', '2. high': '139.1600', '3. low': '127.2200', '4. close': '130.8600', '5. volume': '477625238'}, '2023-08-31': {'1. open': '130.7750', '2. high': '138.0000', '3. low': '126.3824', '4. close': '136.1700', '5. volume': '593521002'}, '2023-07-31': {'1. open': '119.2400', '2. high': '133.7400', '3. low': '115.3500', '4. close': '132.7200', '5. volume': '707114432'}, '2023-06-30': {'1. open': '122.8150', '2. high': '129.0400', '3. low': '116.1000', '4. close': '119.7000', '5. volume': '656884438'}, '2023-05-31': {'1. open': '106.8400', '2. high': '126.4300', '3. low': '103.7100', '4. close': '122.8700', '5. volume': '820529683'}, '2023-04-28': {'1. open': '102.3900', '2. high': '109.1700', '3. low': '101.9300', '4. close': '107.3400', '5. volume': '603728992'}, '2023-03-31': {'1. open': '89.9800', '2. high': '106.5900', '3. low': '89.4200', '4. close': '103.7300', '5. volume': '860049034'}, '2023-02-28': {'1. open': '98.7100', '2. high': '108.1800', '3. low': '88.5750', '4. close': '90.0600', '5. volume': '952709694'}, '2023-01-31': {'1. open': '89.5850', '2. high': '100.3200', '3. low': '84.8600', '4. close': '98.8400', '5. volume': '672897542'}, '2022-12-30': {'1. open': '101.0200', '2. high': '102.2500', '3. low': '85.9400', '4. close': '88.2300', '5. volume': '602717061'}, '2022-11-30': {'1. open': '95.4500', '2. high': '101.0400', '3. low': '83.3400', '4. close': '100.9900', '5. volume': '716537649'}, '2022-10-31': {'1. open': '96.7600', '2. high': '104.8200', '3. low': '91.8000', '4. close': '94.5100', '5. volume': '681653109'}, '2022-09-30': {'1. open': '108.2800', '2. high': '111.6200', '3. low': '95.5600', '4. close': '95.6500', '5. volume': '612908183'}, '2022-08-31': {'1. open': '115.3000', '2. high': '122.4300', '3. low': '107.8000', '4. close': '108.2200', '5. volume': '515791070'}, '2022-07-29': {'1. open': '2158.6600', '2. high': '2393.7000', '3. low': '104.0700', '4. close': '116.3200', '5. volume': '428144985'}, '2022-06-30': {'1. open': '2297.1000', '2. high': '2386.9400', '3. low': '2100.9200', '4. close': '2179.2600', '5. volume': '38543689'}, '2022-05-31': {'1. open': '2268.1000', '2. high': '2457.0900', '3. low': '2037.6936', '4. close': '2275.2400', '5. volume': '42514648'}, '2022-04-29': {'1. open': '2790.0000', '2. high': '2874.2400', '3. low': '2254.7301', '4. close': '2282.1900', '5. volume': '37720682'}, '2022-03-31': {'1. open': '2697.5700', '2. high': '2875.8700', '3. low': '2505.5000', '4. close': '2781.3500', '5. volume': '36383218'}, '2022-02-28': {'1. open': '2751.8900', '2. high': '3030.9315', '3. low': '2499.0650', '4. close': '2701.1400', '5. volume': '46381207'}, '2022-01-31': {'1. open': '2901.1000', '2. high': '2929.6978', '3. low': '2490.0000', '4. close': '2706.0700', '5. volume': '38092594'}, '2021-12-31': {'1. open': '2880.0000', '2. high': '2982.0000', '3. low': '2786.4200', '4. close': '2897.0400', '5. volume': '30992881'}, '2021-11-30': {'1. open': '2960.9200', '2. high': '3019.3300', '3. low': '2832.0300', '4. close': '2837.9500', '5. volume': '30278875'}, '2021-10-29': {'1. open': '2688.9500', '2. high': '2973.0000', '3. low': '2621.0000', '4. close': '2960.9200', '5. volume': '36040000'}, '2021-09-30': {'1. open': '2900.0000 ...

# %%
# .T transposes the data -- reversing the rows and columns
google = pd.DataFrame(data[0]['Monthly Time Series']).T
google = google.reset_index()
google = google.rename(columns = {'index': 'date',
                                 '1. open': 'open',
                                 '2. high': 'high',
                                 '3. low': 'low',
                                 '4. close': 'close',
                                 '5. volume': 'volume'})
google
# Out:
#            date      open      high       low     close     volume
# 0    2024-01-02  138.5500  139.4500  136.4800  138.1700   23599843
# 1    2023-12-29  131.8600  142.6800  127.9000  139.6900  619214883
# 2    2023-11-30  124.0700  139.4200  123.7150  132.5300  535336827
# 3    2023-10-31  131.2100  141.2200  120.2057  124.0800  680762930
# 4    2023-09-29  137.4550  139.1600  127.2200  130.8600  477625238
# ..          ...       ...       ...       ...       ...        ...
# 228  2005-01-31  197.4000  205.3000  176.2900  195.6200  409918400
# 229  2004-12-31  181.7700  199.8800  168.4700  192.7900  290392600
# 230  2004-11-30  193.5000  201.6000  161.3100  181.9800  554632100
# 231  2004-10-29  130.8000  199.9500  128.9000  190.6400  513620700
# 232  2004-09-30  102.7000  135.0200   98.9400  129.6000  212494700
#
# [233 rows x 6 columns]

# %%
amazon = pd.DataFrame(data[1]['Monthly Time Series']).T
amazon = amazon.reset_index()
amazon = amazon.rename(columns = {'index': 'date',
                                 '1. open': 'open',
                                 '2. high': 'high',
                                 '3. low': 'low',
                                 '4. close': 'close',
                                 '5. volume': 'volume'})
amazon
# Out:
#            date      open      high       low     close      volume
# 0    2024-01-02  151.5400  152.3800  148.3900  149.9300    45255327
# 1    2023-12-29  146.0000  155.6300  142.8100  151.9400   930652363
# 2    2023-11-30  133.9600  149.2600  133.7100  146.0900  1026201791
# 3    2023-10-31  127.2800  134.4800  118.3500  133.0900  1224706726
# 4    2023-09-29  139.4550  145.8600  123.0400  127.1200  1120523243
# ..          ...       ...       ...       ...       ...         ...
# 285  2000-04-28   65.4400   68.6300   40.8100   55.1900   162012500
# 286  2000-03-31   67.6300   75.2500   60.0000   67.0000   156584600
# 287  2000-02-29   67.5000   85.9400   63.0600   68.8800   207457700
# 288  2000-01-31   81.5000   91.5000   58.4400   64.5600   262209000
# 289  1999-12-31   87.2500  113.0000   76.0000   76.1300   246476100
#
# [290 rows x 6 columns]

# %%
apple = pd.DataFrame(data[2]['Monthly Time Series']).T
apple = apple.reset_index()
apple = apple.rename(columns = {'index': 'date',
                                 '1. open': 'open',
                                 '2. high': 'high',
                                 '3. low': 'low',
                                 '4. close': 'close',
                                 '5. volume': 'volume'})
apple
# Out:
#            date      open      high       low     close      volume
# 0    2024-01-02  187.1500  188.4400  183.8850  185.6400    79823882
# 1    2023-12-29  190.3300  199.6200  187.4511  192.5300  1062317718
# 2    2023-11-30  171.0000  192.9300  170.1200  189.9500  1099760711
# 3    2023-10-31  171.2200  182.3400  165.6700  170.7700  1172845791
# 4    2023-09-29  189.4850  189.9800  167.6200  171.2100  1337873796
# ..          ...       ...       ...       ...       ...         ...
# 285  2000-04-28  135.5000  139.5000  104.8700  124.0600    77342900
# 286  2000-03-31  118.5600  150.3800  114.0000  135.8100    77663900
# 287  2000-02-29  104.0000  119.9400   97.0000  114.6200    65355200
# 288  2000-01-31  104.8700  121.5000   86.5000  103.7500   112099800
# 289  1999-12-31  101.0000  118.0000   91.0600  102.8100    84091200
#
# [290 rows x 6 columns]

# %%
meta = pd.DataFrame(data[3]['Monthly Time Series']).T
meta = meta.reset_index()
meta = meta.rename(columns = {'index': 'date',
                                 '1. open': 'open',
                                 '2. high': 'high',
                                 '3. low': 'low',
                                 '4. close': 'close',
                                 '5. volume': 'volume'})
meta
# Out:
#            date      open      high       low     close      volume
# 0    2024-01-02  351.3200  353.1600  340.0100  346.2900    18048153
# 1    2023-12-29  325.4800  361.9000  313.6600  353.9600   334028198
# 2    2023-11-30  301.8500  342.9200  301.8500  327.1500   329354280
# 3    2023-10-31  302.7400  330.5400  279.4030  301.2700   511372074
# 4    2023-09-29  299.3700  312.8700  286.7900  300.2100   406801410
# ..          ...       ...       ...       ...       ...         ...
# 135  2012-10-31   22.0800   24.2500   18.8000   21.1100  1100938300
# 136  2012-09-28   18.0800   23.3700   17.5500   21.6600  1058643700
# 137  2012-08-31   21.5000   22.4500   18.0300   18.0580  1151944900
# 138  2012-07-31   31.2500   32.8800   21.6100   21.7100   520189700
# 139  2012-06-29   28.8920   33.4500   25.5200   31.0950   667910500
#
# [140 rows x 6 columns]

# %%
microsoft = pd.DataFrame(data[4]['Monthly Time Series']).T
microsoft = microsoft.reset_index()
microsoft = microsoft.rename(columns = {'index': 'date',
                                 '1. open': 'open',
                                 '2. high': 'high',
                                 '3. low': 'low',
                                 '4. close': 'close',
                                 '5. volume': 'volume'})
microsoft
# Out:
#            date      open      high       low     close      volume
# 0    2024-01-02  373.8600  375.9000  366.7710  370.8700    24824827
# 1    2023-12-29  376.7600  378.1600  362.9000  376.0400   521914675
# 2    2023-11-30  339.7900  384.3000  339.6500  378.9100   564165364
# 3    2023-10-31  316.2800  346.2000  311.2150  338.1100   540963749
# 4    2023-09-29  331.3100  340.8600  309.4500  315.7500   416768824
# ..          ...       ...       ...       ...       ...         ...
# 285  2000-04-28   94.4400   96.5000   65.0000   69.7500  1129073300
# 286  2000-03-31   89.6200  115.0000   88.9400  106.2500  1014093800
# 287  2000-02-29   98.5000  110.0000   88.1200   89.3700   667243800
# 288  2000-01-31  117.3700  118.6200   94.8700   97.8700   637437600
# 289  1999-12-31   91.0600  119.9400   90.8700  116.7500   630488900
#
# [290 rows x 6 columns]

# %%
snap = pd.DataFrame(data[5]['Monthly Time Series']).T
snap = snap.reset_index()
snap = snap.rename(columns = {'index': 'date',
                                 '1. open': 'open',
                                 '2. high': 'high',
                                 '3. low': 'low',
                                 '4. close': 'close',
                                 '5. volume': 'volume'})
snap
# Out:
#           date     open     high      low    close     volume
# 0   2024-01-02  16.5200  16.5550  15.9300  16.1400   29610494
# 1   2023-12-29  13.7500  17.9000  13.6150  16.9300  529789892
# 2   2023-11-30   9.9500  14.2300   9.8100  13.8300  435242899
# 3   2023-10-31   8.8700  10.8700   8.3950  10.0100  670955996
# 4   2023-09-29  10.4100  10.6000   8.2800   8.9100  375739567
# ..         ...      ...      ...      ...      ...        ...
# 77  2017-08-31  13.7700  15.3400  11.2800  14.5100  940242480
# 78  2017-07-31  17.9100  17.9200  13.1000  13.6700  344478210
# 79  2017-06-30  21.3200  21.4500  17.0000  17.7700  313557240
# 80  2017-05-31  22.6600  23.5700  17.5900  21.2100  602353722
# 81  2017-04-28  22.7000  22.9000  19.7300  22.5500  231994583
#
# [82 rows x 6 columns]

# %%
print(google["close"])
# Out:
# 0      138.1700
# 1      139.6900
# 2      132.5300
# 3      124.0800
# 4      130.8600
#          ...
# 228    195.6200
# 229    192.7900
# 230    181.9800
# 231    190.6400
# 232    129.6000
# Name: close, Length: 233, dtype: object

# %%
google.dtypes
# Out:
# date      object
# open      object
# high      object
# low       object
# close     object
# volume    object
# dtype: object

# %%
google = google.astype({"close": float}, errors='raise')
amazon = amazon.astype({"close": float}, errors='raise')
apple = apple.astype({"close": float}, errors='raise')
meta = meta.astype({"close": float}, errors='raise')
microsoft = microsoft.astype({"close": float}, errors='raise')
snap = snap.astype({"close": float}, errors='raise')

# %%
google = google.astype({"open": float}, errors='raise')
amazon = amazon.astype({"open": float}, errors='raise')
apple = apple.astype({"open": float}, errors='raise')
meta = meta.astype({"open": float}, errors='raise')
microsoft = microsoft.astype({"open": float}, errors='raise')
snap = snap.astype({"open": float}, errors='raise')

# %%
google = google.astype({"volume": float}, errors='raise')
amazon = amazon.astype({"volume": float}, errors='raise')
apple = apple.astype({"volume": float}, errors='raise')
meta = meta.astype({"volume": float}, errors='raise')
microsoft = microsoft.astype({"volume": float}, errors='raise')
snap = snap.astype({"volume": float}, errors='raise')

# %%
google["dates"] = [datetime.datetime.strptime(ts, "%Y-%m-%d") for ts in google["date"]]
google["dates"]
# Out:
# 0     2024-01-02
# 1     2023-12-29
# 2     2023-11-30
# 3     2023-10-31
# 4     2023-09-29
#          ...
# 228   2005-01-31
# 229   2004-12-31
# 230   2004-11-30
# 231   2004-10-29
# 232   2004-09-30
# Name: dates, Length: 233, dtype: datetime64[ns]

# %%
google = google.loc[google["dates"] > "2017-01-01"]
google["dates"]
# Out:
# 0    2024-01-02
# 1    2023-12-29
# 2    2023-11-30
# 3    2023-10-31
# 4    2023-09-29
#         ...
# 80   2017-05-31
# 81   2017-04-28
# 82   2017-03-31
# 83   2017-02-28
# 84   2017-01-31
# Name: dates, Length: 85, dtype: datetime64[ns]

# %%
amazon["dates"] = [datetime.datetime.strptime(ts, "%Y-%m-%d") for ts in amazon["date"]]
amazon.dtypes
# Out:
# date              object
# open             float64
# high              object
# low               object
# close            float64
# volume           float64
# dates     datetime64[ns]
# dtype: object

# %%
amazon = amazon.loc[amazon["dates"] > "2017-01-01"]
amazon["dates"]
# Out:
# 0    2024-01-02
# 1    2023-12-29
# 2    2023-11-30
# 3    2023-10-31
# 4    2023-09-29
#         ...
# 80   2017-05-31
# 81   2017-04-28
# 82   2017-03-31
# 83   2017-02-28
# 84   2017-01-31
# Name: dates, Length: 85, dtype: datetime64[ns]

# %%
apple["dates"] = [datetime.datetime.strptime(ts, "%Y-%m-%d") for ts in apple["date"]]
apple.dtypes
# Out:
# date              object
# open             float64
# high              object
# low               object
# close            float64
# volume           float64
# dates     datetime64[ns]
# dtype: object

# %%
apple = apple.loc[apple["dates"] > "2017-01-01"]
apple
# Out:
#           date     open      high       low   close        volume      dates
# 0   2024-01-02  187.150  188.4400  183.8850  185.64  7.982388e+07 2024-01-02
# 1   2023-12-29  190.330  199.6200  187.4511  192.53  1.062318e+09 2023-12-29
# 2   2023-11-30  171.000  192.9300  170.1200  189.95  1.099761e+09 2023-11-30
# 3   2023-10-31  171.220  182.3400  165.6700  170.77  1.172846e+09 2023-10-31
# 4   2023-09-29  189.485  189.9800  167.6200  171.21  1.337874e+09 2023-09-29
# ..         ...      ...       ...       ...     ...           ...        ...
# 80  2017-05-31  145.100  156.6500  144.2700  152.76  6.352930e+08 2017-05-31
# 81  2017-04-28  143.710  145.4600  140.0600  143.65  3.712802e+08 2017-04-28
# 82  2017-03-31  137.890  144.5000  137.0500  143.66  5.620912e+08 2017-03-31
# 83  2017-02-28  127.030  137.4800  127.0100  136.99  5.749685e+08 2017-02-28
# 84  2017-01-31  115.800  122.4400  114.7600  121.35  5.633312e+08 2017-01-31
#
# [85 rows x 7 columns]

# %%
meta["dates"] = [datetime.datetime.strptime(ts, "%Y-%m-%d") for ts in meta["date"]]
meta.dtypes
# Out:
# date              object
# open             float64
# high              object
# low               object
# close            float64
# volume           float64
# dates     datetime64[ns]
# dtype: object

# %%
meta = meta.loc[meta["dates"] > "2017-01-01"]
meta["dates"]
# Out:
# 0    2024-01-02
# 1    2023-12-29
# 2    2023-11-30
# 3    2023-10-31
# 4    2023-09-29
#         ...
# 80   2017-05-31
# 81   2017-04-28
# 82   2017-03-31
# 83   2017-02-28
# 84   2017-01-31
# Name: dates, Length: 85, dtype: datetime64[ns]

# %%
microsoft["dates"] = [datetime.datetime.strptime(ts, "%Y-%m-%d") for ts in microsoft["date"]]
microsoft.dtypes
# Out:
# date              object
# open             float64
# high              object
# low               object
# close            float64
# volume           float64
# dates     datetime64[ns]
# dtype: object

# %%
microsoft = microsoft.loc[microsoft["dates"] > "2017-01-01"]
microsoft["dates"]
# Out:
# 0    2024-01-02
# 1    2023-12-29
# 2    2023-11-30
# 3    2023-10-31
# 4    2023-09-29
#         ...
# 80   2017-05-31
# 81   2017-04-28
# 82   2017-03-31
# 83   2017-02-28
# 84   2017-01-31
# Name: dates, Length: 85, dtype: datetime64[ns]

# %%
snap["dates"] = [datetime.datetime.strptime(ts, "%Y-%m-%d") for ts in snap["date"]]
snap.dtypes
# Out:
# date              object
# open             float64
# high              object
# low               object
# close            float64
# volume           float64
# dates     datetime64[ns]
# dtype: object

# %%
snap = snap.loc[snap["dates"] > "2017-01-01"]
snap["dates"]
# Out:
# 0    2024-01-02
# 1    2023-12-29
# 2    2023-11-30
# 3    2023-10-31
# 4    2023-09-29
#         ...
# 77   2017-08-31
# 78   2017-07-31
# 79   2017-06-30
# 80   2017-05-31
# 81   2017-04-28
# Name: dates, Length: 82, dtype: datetime64[ns]

# %%
google.dtypes
# Out:
# date              object
# open             float64
# high              object
# low               object
# close            float64
# volume           float64
# dates     datetime64[ns]
# dtype: object

# %%
fig, ax1 = plt.subplots()

x_axis = google['dates']
y_axis = google["close"]

GoogleChange, = plt.plot(x_axis, y_axis, linewidth=1, color='g', label="Google Stock")
plt.title("Google Value Over Time")
plt.xlabel("Date")
plt.ylabel("Closing Value")

plt.legend(handles=[GoogleChange], loc="upper right")

fig.tight_layout()
plt.show()

# %%
fig, ax1 = plt.subplots()

x_axis = apple['dates']
y_axis = apple["close"]

AppleChange, = plt.plot(x_axis, y_axis, linewidth=1, color='g', label="Apple Stock")
plt.title("Apple Value Over Time")
plt.xlabel("Date")
plt.ylabel("Closing Value")

plt.legend(handles=[AppleChange], loc="upper right")

fig.tight_layout()
plt.show()

# %%
fig, ax1 = plt.subplots()

x_axis = amazon['dates']
y_axis = amazon["close"]

AmazonChange, = plt.plot(x_axis, y_axis, linewidth=1, color='g', label="Amazon Stock")
plt.title("Amazon Value Over Time")
plt.xlabel("Date")
plt.ylabel("Closing Value")

plt.legend(handles=[AmazonChange], loc="upper right")

fig.tight_layout()
plt.show()

# %%
fig, ax1 = plt.subplots()

x_axis = meta['dates']
y_axis = meta["close"]

MetaChange, = plt.plot(x_axis, y_axis, linewidth=1, color='g', label="Meta Stock")
plt.title("Meta Value Over Time")
plt.xlabel("Date")
plt.ylabel("Closing Value")

plt.legend(handles=[MetaChange], loc="upper right")

fig.tight_layout()
plt.show()

# %%
fig, ax1 = plt.subplots()

x_axis = microsoft['dates']
y_axis = microsoft["close"]

MicrosoftChange, = plt.plot(x_axis, y_axis, linewidth=1, color='g', label="Microsoft Stock")
plt.title("Microsoft Value Over Time")
plt.xlabel("Date")
plt.ylabel("Closing Value")

plt.legend(handles=[MicrosoftChange], loc="upper right")

fig.tight_layout()
plt.show()

# %%
fig, ax1 = plt.subplots()

x_axis = snap['dates']
y_axis = snap["close"]

SnapChange, = plt.plot(x_axis, y_axis, linewidth=1, color='g', label="Snapchat Stock")
plt.title("Snapchat Value Over Time")
plt.xlabel("Date")
plt.ylabel("Closing Value")

plt.legend(handles=[SnapChange], loc="upper right")

fig.tight_layout()
plt.show()

# %%
google["stock_id"] = "GOOGL"
google["stock_id"]
# Out:
# 0     GOOGL
# 1     GOOGL
# 2     GOOGL
# 3     GOOGL
# 4     GOOGL
#       ...
# 80    GOOGL
# 81    GOOGL
# 82    GOOGL
# 83    GOOGL
# 84    GOOGL
# Name: stock_id, Length: 85, dtype: object

# %%
amazon["stock_id"] = "AMZN"
amazon["stock_id"]
# Out:
# C:\Users\emmar\AppData\Local\Temp\ipykernel_720\1271821589.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amazon["stock_id"] = "AMZN"
# 0     AMZN
# 1     AMZN
# 2     AMZN
# 3     AMZN
# 4     AMZN
#       ...
# 80    AMZN
# 81    AMZN
# 82    AMZN
# 83    AMZN
# 84    AMZN
# Name: stock_id, Length: 85, dtype: object

# %%
apple["stock_id"] = "AAPL"
apple["stock_id"]
# Out:
# 0     AAPL
# 1     AAPL
# 2     AAPL
# 3     AAPL
# 4     AAPL
#       ...
# 80    AAPL
# 81    AAPL
# 82    AAPL
# 83    AAPL
# 84    AAPL
# Name: stock_id, Length: 85, dtype: object

# %%
meta["stock_id"] = "META"
meta["stock_id"]
# Out:
# 0     META
# 1     META
# 2     META
# 3     META
# 4     META
#       ...
# 80    META
# 81    META
# 82    META
# 83    META
# 84    META
# Name: stock_id, Length: 85, dtype: object

# %%
microsoft["stock_id"] = "MSFT"
microsoft["stock_id"]
# Out:
# 0      MSFT
# 1      MSFT
# 2      MSFT
# 3      MSFT
# 4      MSFT
#        ...
# 285    MSFT
# 286    MSFT
# 287    MSFT
# 288    MSFT
# 289    MSFT
# Name: stock_id, Length: 290, dtype: object

# %%
snap["stock_id"] = "SNAP" 
snap["stock_id"]
# Out:
# 0     SNAP
# 1     SNAP
# 2     SNAP
# 3     SNAP
# 4     SNAP
#       ...
# 77    SNAP
# 78    SNAP
# 79    SNAP
# 80    SNAP
# 81    SNAP
# Name: stock_id, Length: 82, dtype: object

# %%
apple_reduced = apple[["stock_id", "dates", "open", "close", "volume"]]
apple_reduced
# Out:
#     stock_id      dates     open   close        volume
# 0       AAPL 2024-01-02  187.030  185.64  7.991231e+07
# 1       AAPL 2023-12-29  190.330  192.53  1.062318e+09
# 2       AAPL 2023-11-30  171.000  189.95  1.099761e+09
# 3       AAPL 2023-10-31  171.220  170.77  1.172846e+09
# 4       AAPL 2023-09-29  189.485  171.21  1.337874e+09
# ..       ...        ...      ...     ...           ...
# 285     AAPL 2000-04-28  135.500  124.06  7.734290e+07
# 286     AAPL 2000-03-31  118.560  135.81  7.766390e+07
# 287     AAPL 2000-02-29  104.000  114.62  6.535520e+07
# 288     AAPL 2000-01-31  104.870  103.75  1.120998e+08
# 289     AAPL 1999-12-31  101.000  102.81  8.409120e+07
#
# [290 rows x 5 columns]

# %%
amazon_reduced = amazon[["stock_id", "dates", "open", "close", "volume"]]
amazon_reduced
# Out:
#     stock_id      dates     open   close        volume
# 0       AMZN 2024-01-02  151.640  149.93  4.525625e+07
# 1       AMZN 2023-12-29  146.000  151.94  9.306524e+08
# 2       AMZN 2023-11-30  133.960  146.09  1.026202e+09
# 3       AMZN 2023-10-31  127.280  133.09  1.224707e+09
# 4       AMZN 2023-09-29  139.455  127.12  1.120523e+09
# ..       ...        ...      ...     ...           ...
# 285     AMZN 2000-04-28   65.440   55.19  1.620125e+08
# 286     AMZN 2000-03-31   67.630   67.00  1.565846e+08
# 287     AMZN 2000-02-29   67.500   68.88  2.074577e+08
# 288     AMZN 2000-01-31   81.500   64.56  2.622090e+08
# 289     AMZN 1999-12-31   87.250   76.13  2.464761e+08
#
# [290 rows x 5 columns]

# %%
google_reduced = google[["stock_id", "dates", "open", "close", "volume"]]
google_reduced
# Out:
#     stock_id      dates     open   close       volume
# 0      GOOGL 2024-01-02  138.660  138.17   23600504.0
# 1      GOOGL 2023-12-29  131.860  139.69  619214883.0
# 2      GOOGL 2023-11-30  124.070  132.53  535336827.0
# 3      GOOGL 2023-10-31  131.210  124.08  680762930.0
# 4      GOOGL 2023-09-29  137.455  130.86  477625238.0
# ..       ...        ...      ...     ...          ...
# 228    GOOGL 2005-01-31  197.400  195.62  409918400.0
# 229    GOOGL 2004-12-31  181.770  192.79  290392600.0
# 230    GOOGL 2004-11-30  193.500  181.98  554632100.0
# 231    GOOGL 2004-10-29  130.800  190.64  513620700.0
# 232    GOOGL 2004-09-30  102.700  129.60  212494700.0
#
# [233 rows x 5 columns]

# %%
meta_reduced = meta[["stock_id", "dates", "open", "close", "volume"]]
meta_reduced
# Out:
#     stock_id      dates     open    close        volume
# 0       META 2024-01-02  351.550  346.290  1.804932e+07
# 1       META 2023-12-29  325.480  353.960  3.340282e+08
# 2       META 2023-11-30  301.850  327.150  3.293543e+08
# 3       META 2023-10-31  302.740  301.270  5.113721e+08
# 4       META 2023-09-29  299.370  300.210  4.068014e+08
# ..       ...        ...      ...      ...           ...
# 135     META 2012-10-31   22.080   21.110  1.100938e+09
# 136     META 2012-09-28   18.080   21.660  1.058644e+09
# 137     META 2012-08-31   21.500   18.058  1.151945e+09
# 138     META 2012-07-31   31.250   21.710  5.201897e+08
# 139     META 2012-06-29   28.892   31.095  6.679105e+08
#
# [140 rows x 5 columns]

# %%
microsoft_reduced = microsoft[["stock_id", "dates", "open", "close", "volume"]]
microsoft_reduced
# Out:
#     stock_id      dates    open   close        volume
# 0       MSFT 2024-01-02  373.69  370.87  2.482497e+07
# 1       MSFT 2023-12-29  376.76  376.04  5.219147e+08
# 2       MSFT 2023-11-30  339.79  378.91  5.641654e+08
# 3       MSFT 2023-10-31  316.28  338.11  5.409637e+08
# 4       MSFT 2023-09-29  331.31  315.75  4.167688e+08
# ..       ...        ...     ...     ...           ...
# 285     MSFT 2000-04-28   94.44   69.75  1.129073e+09
# 286     MSFT 2000-03-31   89.62  106.25  1.014094e+09
# 287     MSFT 2000-02-29   98.50   89.37  6.672438e+08
# 288     MSFT 2000-01-31  117.37   97.87  6.374376e+08
# 289     MSFT 1999-12-31   91.06  116.75  6.304889e+08
#
# [290 rows x 5 columns]

# %%
snap_reduced = snap[["stock_id", "dates", "open", "close", "volume"]]
snap_reduced
# Out:
#    stock_id      dates   open  close       volume
# 0      SNAP 2024-01-02  16.52  16.14   29663175.0
# 1      SNAP 2023-12-29  13.75  16.93  529789892.0
# 2      SNAP 2023-11-30   9.95  13.83  435242899.0
# 3      SNAP 2023-10-31   8.87  10.01  670955996.0
# 4      SNAP 2023-09-29  10.41   8.91  375739567.0
# ..      ...        ...    ...    ...          ...
# 77     SNAP 2017-08-31  13.77  14.51  940242480.0
# 78     SNAP 2017-07-31  17.91  13.67  344478210.0
# 79     SNAP 2017-06-30  21.32  17.77  313557240.0
# 80     SNAP 2017-05-31  22.66  21.21  602353722.0
# 81     SNAP 2017-04-28  22.70  22.55  231994583.0
#
# [82 rows x 5 columns]

# %%
stock_df = pd.concat([apple_reduced, amazon_reduced, google_reduced, meta_reduced, microsoft_reduced, snap_reduced])
stock_df
# Out:
#    stock_id      dates     open   close        volume
# 0      AAPL 2024-01-02  187.030  185.64  7.991231e+07
# 1      AAPL 2023-12-29  190.330  192.53  1.062318e+09
# 2      AAPL 2023-11-30  171.000  189.95  1.099761e+09
# 3      AAPL 2023-10-31  171.220  170.77  1.172846e+09
# 4      AAPL 2023-09-29  189.485  171.21  1.337874e+09
# ..      ...        ...      ...     ...           ...
# 77     SNAP 2017-08-31   13.770   14.51  9.402425e+08
# 78     SNAP 2017-07-31   17.910   13.67  3.444782e+08
# 79     SNAP 2017-06-30   21.320   17.77  3.135572e+08
# 80     SNAP 2017-05-31   22.660   21.21  6.023537e+08
# 81     SNAP 2017-04-28   22.700   22.55  2.319946e+08
#
# [1325 rows x 5 columns]

# %%
stock_df.to_csv("stockData.csv", index=False, header=True)
